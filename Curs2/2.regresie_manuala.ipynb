# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
apartamente = [(37, 65), (55, 80), (80, 120), (60, 95), (92, 205), (41, 75), (170, 400), (145, 367), (82, 205), (72, 198)]

apartamente = np.array(apartamente)

apartamente = apartamente[ apartamente[:,0].argsort()]
suprafete, preturi = apartamente[:, 0], apartamente[:, 1]

# %%
plt.rcParams["figure.figsize"] = [3.3, 3.3]

# %%
def lin_plot(x, y, a, b):
    plt.scatter(x, y);
    f = lambda x: a * x + b
    plt.plot(x, list(map(f, x)));

# %%
lin_plot(suprafete, preturi, 20, 30)

# %%
lin_plot(x=suprafete, y=preturi, a=0, b=0)

# %%
lin_plot(x=suprafete, y=preturi, a=1, b=20)

# %% [markdown]
# # Preturile reale

# %%
preturi
# Out:
# array([ 65,  75,  80,  95, 198, 120, 205, 205, 367, 400])

# %%
suprafete
# Out:
# array([ 37,  41,  55,  60,  72,  80,  82,  92, 145, 170])

# %%
a = 1
b = 1
preturi_calculate = a *  suprafete + 1
preturi_calculate
# Out:
# array([ 38,  42,  56,  61,  73,  81,  83,  93, 146, 171])

# %%
preturi - preturi_calculate
# Out:
# array([ 27,  33,  24,  34, 125,  39, 122, 112, 221, 229])

# %%
(preturi - preturi_calculate) ** 2
# Out:
# array([  729,  1089,   576,  1156, 15625,  1521, 14884, 12544, 48841,
#        52441])

# %%
((preturi - preturi_calculate) ** 2).sum()
# Out:
# np.int64(149406)

# %%
np.sqrt(((preturi - preturi_calculate) ** 2).sum())
# Out:
# np.float64(386.53072322908565)

# %%
lin_plot(suprafete, preturi, 1, 1)

# %%
a = 2
b = 1
preturi_calculate = a *  suprafete + 1
preturi_calculate

np.sqrt(((preturi - preturi_calculate) ** 2).sum())
# Out:
# np.float64(132.4688642662871)

# %%
lin_plot(suprafete, preturi, 2, 1)

# %%
a = 2
b = 10
preturi_calculate = a *  suprafete + b
preturi_calculate

np.sqrt(((preturi - preturi_calculate) ** 2).sum())
# Out:
# np.float64(126.4199351368288)

# %%
lin_plot(suprafete, preturi, 2, 10)

# %% [markdown]
# # Intuitie ML

# %% [markdown]
# Cum am imbunatatit eroare?
#  - am modificat a
#  - am modificat b

# %% [markdown]
# 1. INCEPEM CU a si b - random (sau 0 si 0)

# %% [markdown]
# 2. Ajustam pe a si b
