# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.datasets import make_regression

# %%
make_regression(n_samples=2, n_features=1)
# Out:
# (array([[-0.54992701],
#         [ 0.03413966]]),
#  array([-18.20061746,   1.12990066]))

# %%
make_regression(n_samples=3, n_features=1)
# Out:
# (array([[1.44150467],
#         [0.6784445 ],
#         [1.2160097 ]]),
#  array([63.63571708, 29.95016474, 53.68116463]))

# %%
make_regression(n_samples=3, n_features=2)
# Out:
# (array([[-1.00227319,  1.62515673],
#         [ 1.2745146 ,  2.23587113],
#         [-0.03687913, -0.22346468]]),
#  array([  6.23115896, 104.65862057,  -7.18285813]))

# %%
x, y = make_regression(n_samples=10, n_features=1)
plt.scatter(x, y);

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x, y);
plt.plot(x, model.coef_ * x + model.intercept_)

# %% [markdown]
# # Adaugare Noise (ZGOMOT)

# %%
x, y = make_regression(n_samples=100, n_features=1, noise=10)
model = LinearRegression()
model.fit(x, y)
plt.scatter(x, y);
plt.plot(x, model.coef_ * x + model.intercept_);

# %%
model.predict([[1]])
# Out:
# array([20.83224384])

# %%
knn_model = KNeighborsRegressor()
knn_model
# Out:
# KNeighborsRegressor()

# %%
knn_model.fit(x, y)
# Out:
# KNeighborsRegressor()

# %%
knn_model.predict([[1]])
# Out:
# array([18.98792697])
