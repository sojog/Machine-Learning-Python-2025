# %%
date = {
"Alina": [60, 165, True],
"Bogdan": [72, 183, False],
"Ciprian": [69, 178, False],
"Diana": [55, 152, True],
"Elena": [58, 168, True],
"Andrei": [80, 185, False],
"Mihai": [75, 177, False],
"Irina": [62, 170, True],
"Florin": [90, 190, False],
"Maria": [53, 160, True],
"Vlad": [70, 175, False],
"Ioana": [50, 155, True],
"Radu": [68, 172, False],
"Ana": [59, 162, True],
"George": [85, 182, False],
"Larisa": [61, 167, True],
"Stefan": [78, 180, False],
"Bianca": [56, 158, True],
"Paul": [74, 176, False],
"Oana": [54, 163, True],
"Cosmin": [82, 188, False],
"Teodora": [57, 159, True],
"Ionut": [76, 181, False],
"Gabriela": [60, 164, True]
}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(data=date)
df
# Out:
#   Alina Bogdan Ciprian Diana Elena Andrei  Mihai Irina Florin Maria  ...  \
# 0    60     72      69    55    58     80     75    62     90    53  ...
# 1   165    183     178   152   168    185    177   170    190   160  ...
# 2  True  False   False  True  True  False  False  True  False  True  ...
#
#   George Larisa Stefan Bianca   Paul  Oana Cosmin Teodora  Ionut Gabriela
# 0     85     61     78     56     74    54     82      57     76       60
# 1    182    167    180    158    176   163    188     159    181      164
# 2  False   True  False   True  False  True  False    True  False     True
#
# [3 rows x 24 columns]

# %%
df = pd.DataFrame.from_dict(date, orient="index", columns=["Greutate", "Inaltime", "Voce_Subtire"])
df
# Out:
#           Greutate  Inaltime  Voce_Subtire
# Alina           60       165          True
# Bogdan          72       183         False
# Ciprian         69       178         False
# Diana           55       152          True
# Elena           58       168          True
# Andrei          80       185         False
# Mihai           75       177         False
# Irina           62       170          True
# Florin          90       190         False
# Maria           53       160          True
# Vlad            70       175         False
# Ioana           50       155          True
# Radu            68       172         False
# Ana             59       162          True
# George          85       182         False
# Larisa          61       167          True
# Stefan          78       180         False
# Bianca          56       158          True
# Paul            74       176         False
# Oana            54       163          True
# Cosmin          82       188         False
# ...

# %%
df.to_json("oameni_greutati_inaltimi.json")

# %%
new_df = pd.read_json("oameni_greutati_inaltimi.json")
new_df.head(2)
# Out:
#         Greutate  Inaltime  Voce_Subtire
# Alina         60       165          True
# Bogdan        72       183         False

# %%
df["Gen"] = df["Voce_Subtire"] == False

# %%
df
# Out:
#           Greutate  Inaltime  Voce_Subtire    Gen
# Alina           60       165          True  False
# Bogdan          72       183         False   True
# Ciprian         69       178         False   True
# Diana           55       152          True  False
# Elena           58       168          True  False
# Andrei          80       185         False   True
# Mihai           75       177         False   True
# Irina           62       170          True  False
# Florin          90       190         False   True
# Maria           53       160          True  False
# Vlad            70       175         False   True
# Ioana           50       155          True  False
# Radu            68       172         False   True
# Ana             59       162          True  False
# George          85       182         False   True
# Larisa          61       167          True  False
# Stefan          78       180         False   True
# Bianca          56       158          True  False
# ...

# %%
y = df["Gen"]

# %%
x = df[["Greutate",	"Inaltime", "Voce_Subtire"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier()

# %%
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_model.score(x_test, y_test)
# Out:
# 1.0

# %%
plt.scatter(x["Greutate"], x["Inaltime"], c=x["Voce_Subtire"]);
