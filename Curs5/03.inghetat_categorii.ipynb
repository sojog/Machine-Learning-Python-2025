# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("date_inghetata.csv")
df
# Out:
#      temperatura  vanzari      luna zi_saptamana
# 0              8       25  ianuarie         luni
# 1             10       35  ianuarie        marti
# 2             12       45  ianuarie     miercuri
# 3             15       55  ianuarie          joi
# 4             18       75  ianuarie       vineri
# ..           ...      ...       ...          ...
# 233           33      168       mai     miercuri
# 234           35      182       mai          joi
# 235           37      195       mai       vineri
# 236           39      208       mai      sambata
# 237           41      222       mai    duminica
#
# [238 rows x 4 columns]

# %%
df["weekend"] = df["zi_saptamana"].isin(["sambata", "duminica"])

# %%
df
# Out:
#      temperatura  vanzari      luna zi_saptamana  weekend
# 0              8       25  ianuarie         luni    False
# 1             10       35  ianuarie        marti    False
# 2             12       45  ianuarie     miercuri    False
# 3             15       55  ianuarie          joi    False
# 4             18       75  ianuarie       vineri    False
# ..           ...      ...       ...          ...      ...
# 233           33      168       mai     miercuri    False
# 234           35      182       mai          joi    False
# 235           37      195       mai       vineri    False
# 236           39      208       mai      sambata     True
# 237           41      222       mai    duminica     False
#
# [238 rows x 5 columns]

# %%
plt.scatter(df["temperatura"], df["vanzari"], c=df["weekend"]);

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
temperatura = df["temperatura"]
temperatura = np.array(temperatura).reshape(-1, 1)
scaled_x = scaler.fit_transform(temperatura)

vanzari = df["vanzari"]
vanzari = np.array(vanzari).reshape(-1, 1)
scaled_y = scaler.fit_transform(vanzari)

# %%
plt.scatter(scaled_x, scaled_y);
