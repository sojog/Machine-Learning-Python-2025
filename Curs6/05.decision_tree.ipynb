# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("4_categories.csv")
x = df[["coord_x", "coord_y"]]
y = df["category"]

# %%
plt.scatter(df["coord_x"], df["coord_y"]);

# %%
d_colors = {
    "a":"red", "b":"black", "c":"blue", "d":"green"
}

# %%
plt.scatter(df["coord_x"], df["coord_y"], c=df["category"].replace(d_colors));

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
model.fit(x, y)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[200, 100]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['b'], dtype=object)

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
exported_data = export_graphviz(model, feature_names=["coord_x", "coord_y"], class_names=["a", "b", "c", "d"], filled=True, rounded=True)

# %%
graph = graphviz.Source(exported_data)
graph.render("4 Categories", format="png")
graph.view()
# Out:
# '4 Categories.pdf'

# %%
max_range_x = np.arange(0, 800)
orizontal_y = np.ones(800) * 231

# %%
max_range_y = np.arange(0, 500)
veritcal_x = np.ones(500) * 333

# %%
plt.scatter(df["coord_x"], df["coord_y"], c=df["category"].replace(d_colors));
plt.plot(max_range_x, orizontal_y);
plt.plot(veritcal_x, max_range_y);


plt.plot(np.ones(500) * 375, np.arange(0, 500));
